# %% [markdown]
# ## Broken Example by implementing massive force
#
# This can be recognized by looking through the few iterations taht are able to run, as they show the accumulating error.

# %%
from finiteelementanalysis import pre_process as pre
from finiteelementanalysis import pre_process_demo_helper_fcns as pre_demo
from finiteelementanalysis.solver import hyperelastic_solver
from finiteelementanalysis import visualize as viz
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import os

# for saving files later
#tutorials_dir = Path(current_dir).parent

# --- Beam geometry ---
L = 60.0   # length in x
H = 1  # height in y
nx = 60 #40    # number of elements along length
ny = 2     # number of elements along height

ele_type = "D2_nn8_quad"  # 2D, 4-node quadrilateral (linear)
ndof = 2                  # 2 DOFs per node (x, y)

# Generate a rectangular mesh
coords, connect = pre.generate_rect_mesh_2d(ele_type, 0.0, 0.0, L, H, nx, ny)
# coords: shape (n_nodes, 2)
# connect: shape (n_nodes_per_elem, n_elems)

# --- Identify boundaries ---
boundary_nodes, boundary_edges = pre.identify_rect_boundaries(
    coords, connect, ele_type, x_lower=0.0, x_upper=L, y_lower=0.0, y_upper=H
)

# 1) Clamp the left edge: fix x- and y-displacements = 0
fixed_left = pre.assign_fixed_nodes_rect(boundary_nodes, "left", 0.0, 0.0)
fixed_right = pre.assign_fixed_nodes_rect(boundary_nodes, "right", L, 0.0)


# 2) Uniform downward traction on the top edge (y=H)
# Let q be negative in the y-direction
q = -8  # load per unit length in x
# For a 2D plane strain problem, this is a traction (tx, ty) = (0, q)
dload_info = pre.assign_uniform_load_rect(boundary_edges, "top", 0.0, q)

# Combine boundary conditions
fixed_nodes = np.hstack((fixed_left, fixed_right))


# --- Material properties ---
E = 100000.0
nu = 0.3
mu = E / (2.0 * (1.0 + nu))
kappa = E / (3.0 * (1.0 - 2.0 * nu))


material_props = np.array([mu, kappa])
print(f"Material properties: mu={mu:.3f}, kappa={kappa:.3f}")

# Number of incremental load steps
nr_num_steps = 1

# --- Solve with your hyperelastic solver ---
displacements_all, nr_info_all = hyperelastic_solver(
    material_props,
    ele_type,
    coords.T,      # shape (2, n_nodes)
    connect.T,     # shape (n_nodes_per_elem, n_elems)
    fixed_nodes,
    dload_info,
    nr_print=True,
    nr_num_steps=nr_num_steps,
    nr_tol=1e-10,
    nr_maxit=300,
)

final_disp = displacements_all[-1]  # shape: (n_nodes*ndof,)

# --- Compute the tip displacement from the FEA result ---
# We'll pick a node near x=L, y=H/2
tip_node = None
tol = 1e-2
for i, (x, y) in enumerate(coords):
    if abs(x - 0.5*L) < tol and abs(y - H/2) < H/(2*ny):
        tip_node = i
        break
if tip_node is None:
    raise ValueError("Could not find tip node near x=L, y=H/2.")

mid_disp_y = final_disp[ndof*tip_node + 1]  # the y-component of displacement

# --- Compare with Euler–Bernoulli formula for small deflection ---
mu = material_props[0]
# We'll guess E = 3 mu (plane stress, near incompressible) or 2 mu(1 + nu) for plane strain, etc.
# --- Analytical Solution ---
# For a cantilever beam under uniformly distributed load q:
# Euler–Bernoulli tip deflection: w(L) = q * L^4 / (8 * E * I)
# E_eff = E * (1 - nu) / ((1 + nu) * (1 - 2*nu))
E_eff = E / (1 - nu ** 2.0)
I = H ** 3 / 12.0
w_analytical = q * L ** 4 / (8.0 * E_eff * I)

print(f"Tip node index: {tip_node}, coordinates={coords[tip_node]}")
print(f"Computed mid deflection (y): {mid_disp_y:.6f}")
print(f"Analytical Euler-Bernoulli deflection: {w_analytical:.6f}")

# --- Evaluate error ---
error = abs(mid_disp_y - w_analytical)
print(f"Absolute error = {error:.6e}")

tutorials_dir = os.getcwd()

# --- Plot the mesh with the final deformed shape ---

img_name = "implemented_example.gif"
fname = os.path.join(tutorials_dir, img_name)
viz.make_deformation_gif(displacements_all, coords, connect, ele_type, fname)
# Out:
# Material properties: mu=38461.538, kappa=83333.333
# Step 0, load factor = 1.000
# Iteration 1, Correction=1.000000e+00, Residual=1.462546e-01, tolerance=1.000000e-10
# Iteration 2, Correction=3.495184e-01, Residual=2.463024e+03, tolerance=1.000000e-10
# Iteration 3, Correction=0.000000e+00, Residual=nan, tolerance=1.000000e-10
# Tip node index: 242, coordinates=[30.   0.5]
# Computed mid deflection (y): nan
# Analytical Euler-Bernoulli deflection: -1415.232000
# Absolute error = nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 114
#     112 img_name = "implemented_example.gif"
#     113 fname = os.path.join(tutorials_dir, img_name)
# --> 114 viz.make_deformation_gif(displacements_all, coords, connect, ele_type, fname)
#
# File /projectnb/me700/students/mlanduyt/finite-element-analysis/src/finiteelementanalysis/visualize.py:110, in make_deformation_gif(displacements_all, coords, connect, ele_type, gif_path, magnification, interval)
#     108 x_min, x_max = coords[:, 0].min() - max_disp, coords[:, 0].max() + max_disp
#     109 y_min, y_max = coords[:, 1].min() - max_disp, coords[:, 1].max() + max_disp
# --> 110 ax.set_xlim(x_min, x_max)
#     111 ax.set_ylim(y_min, y_max)
#     113 # Compute global maximum displacement magnitude
#
# File /projectnb/me700/students/mlanduyt/.conda/envs/fea-env/lib/python3.13/site-packages/matplotlib/axes/_base.py:3812, in _AxesBase.set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3810         raise TypeError("Cannot pass both 'right' and 'xmax'")
#    3811     right = xmax
# -> 3812 return self.xaxis._set_lim(left, right, emit=emit, auto=auto)
#
# File /projectnb/me700/students/mlanduyt/.conda/envs/fea-env/lib/python3.13/site-packages/matplotlib/axis.py:1216, in Axis._set_lim(self, v0, v1, emit, auto)
#    1213 name = self._get_axis_name()
#    1215 self.axes._process_unit_info([(name, (v0, v1))], convert=False)
# -> 1216 v0 = self.axes._validate_converted_limits(v0, self.convert_units)
#    1217 v1 = self.axes._validate_converted_limits(v1, self.convert_units)
#    1219 if v0 is None or v1 is None:
#    1220     # Axes init calls set_xlim(0, 1) before get_xlim() can be called,
#    1221     # so only grab the limits if we really need them.
#
# File /projectnb/me700/students/mlanduyt/.conda/envs/fea-env/lib/python3.13/site-packages/matplotlib/axes/_base.py:3733, in _AxesBase._validate_converted_limits(self, limit, convert)
#    3730     converted_limit = converted_limit.squeeze()
#    3731 if (isinstance(converted_limit, Real)
#    3732         and not np.isfinite(converted_limit)):
# -> 3733     raise ValueError("Axis limits cannot be NaN or Inf")
#    3734 return converted_limit
#
# ValueError: Axis limits cannot be NaN or Inf
